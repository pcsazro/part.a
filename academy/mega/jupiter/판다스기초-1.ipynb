# %%
import pandas as pd

# %%
# 설치 !pip install pandas

# %%
data_frame = pd.read_csv('day_care_center.csv')

# %%
data_frame
# Out:
#        city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0     서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 1     서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2     서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3     서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4     서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# ...     ...   ...           ...           ...                ...          ...
# 7546  부산광역시   금정구      해바라기어린이집            민간                 46         13.0
# 7547  부산광역시   금정구        해수어린이집            가정                 19          6.0
# 7548  부산광역시   금정구   행복한그림동산어린이집            민간                 92         16.0
# 7549  부산광역시   금정구       행복한어린이집            민간                 43         12.0
# 7550  부산광역시   금정구        혜인어린이집            민간                 32          7.0
#
# ...

# %%
tab = pd.read_csv('data/gapminder.tsv', sep='\t')

# %%
tab
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
tab.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
tab.head(2)
# Out:
#        country continent  year  lifeExp      pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801  8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332  9240934  820.853030

# %%
tab.tail(4)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
type(tab)
# Out:
# pandas.core.frame.DataFrame

# %%
tab.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
tab.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
tab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
# country      1704 non-null object
# continent    1704 non-null object
# year         1704 non-null int64
# lifeExp      1704 non-null float64
# pop          1704 non-null int64
# gdpPercap    1704 non-null float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
contry_df = tab['country']

# %%
type(contry_df)
# Out:
# pandas.core.series.Series

# %%
subset = tab[['country','continent','year']]

# %%
subset
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
sub_list = ['country','year']

# %%
subset2 = tab[sub_list]

# %%
subset2
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
type(subset2)
# Out:
# pandas.core.frame.DataFrame

# %%
tab.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
tab.loc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap        779.445
# Name: 0, dtype: object

# %%
tab.shape
# Out:
# (1704, 6)

# %%
rows1 = [10,50,100,500,1000,1500]
tab_row1 = tab.loc[rows1]

# %%
tab_row1
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 50      Argentina  Americas  1962   65.142  21283783  7133.166023
# 100    Bangladesh      Asia  1972   45.252  70759295   630.233627
# 500       Eritrea    Africa  1992   49.991   3668440   582.858510
# 1000     Mongolia      Asia  1972   53.754   1320500  1421.741975
# 1500       Taiwan      Asia  1952   58.500   8550362  1206.947913

# %%
row2 = tab.loc[840:851]
row2
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 840  Korea, Rep.      Asia  1952   47.453  20947571   1030.592226
# 841  Korea, Rep.      Asia  1957   52.681  22611552   1487.593537
# 842  Korea, Rep.      Asia  1962   55.292  26420307   1536.344387
# 843  Korea, Rep.      Asia  1967   57.716  30131000   2029.228142
# 844  Korea, Rep.      Asia  1972   62.612  33505000   3030.876650
# 845  Korea, Rep.      Asia  1977   64.766  36436000   4657.221020
# 846  Korea, Rep.      Asia  1982   67.123  39326000   5622.942464
# 847  Korea, Rep.      Asia  1987   69.810  41622000   8533.088805
# 848  Korea, Rep.      Asia  1992   72.244  43805450  12104.278720
# 849  Korea, Rep.      Asia  1997   74.647  46173816  15993.527960
# 850  Korea, Rep.      Asia  2002   77.045  47969150  19233.988180
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.139730

# %%
tab.loc[:,['country','year']]
# Out:
#           country  year
# 0     Afghanistan  1952
# 1     Afghanistan  1957
# 2     Afghanistan  1962
# 3     Afghanistan  1967
# 4     Afghanistan  1972
# ...           ...   ...
# 1699     Zimbabwe  1987
# 1700     Zimbabwe  1992
# 1701     Zimbabwe  1997
# 1702     Zimbabwe  2002
# 1703     Zimbabwe  2007
#
# [1704 rows x 2 columns]

# %%
tab.iloc[:,[1,3,5]]
# Out:
#      continent  lifeExp   gdpPercap
# 0         Asia   28.801  779.445314
# 1         Asia   30.332  820.853030
# 2         Asia   31.997  853.100710
# 3         Asia   34.020  836.197138
# 4         Asia   36.088  739.981106
# ...        ...      ...         ...
# 1699    Africa   62.351  706.157306
# 1700    Africa   60.377  693.420786
# 1701    Africa   46.809  792.449960
# 1702    Africa   39.989  672.038623
# 1703    Africa   43.487  469.709298
#
# [1704 rows x 3 columns]

# %%
tab.iloc[:,0]
# Out:
# 0       Afghanistan
# 1       Afghanistan
# 2       Afghanistan
# 3       Afghanistan
# 4       Afghanistan
#            ...
# 1699       Zimbabwe
# 1700       Zimbabwe
# 1701       Zimbabwe
# 1702       Zimbabwe
# 1703       Zimbabwe
# Name: country, Length: 1704, dtype: object

# %%
tab.iloc[:,0:2]
# Out:
#           country continent
# 0     Afghanistan      Asia
# 1     Afghanistan      Asia
# 2     Afghanistan      Asia
# 3     Afghanistan      Asia
# 4     Afghanistan      Asia
# ...           ...       ...
# 1699     Zimbabwe    Africa
# 1700     Zimbabwe    Africa
# 1701     Zimbabwe    Africa
# 1702     Zimbabwe    Africa
# 1703     Zimbabwe    Africa
#
# [1704 rows x 2 columns]

# %%
day_care = pd.read_csv('day_care_center.csv')

# %%
# 행 1,3,5를 추출
row1 = [1,3,5]
day_care.loc[row1]
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 1  서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 5  서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 1               5.0             2.0      10.0                    N
# 3               3.0             0.0       4.0                    N
# 5               3.0             0.0       4.0                    N
#
#   reference_date
# 1     2018-07-31
# 3     2018-07-31
# 5     2018-07-31

# %%
# 행 1부터 100까지 추출
day_care.loc[1:100]
# Out:
#       city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 1    서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 2    서울특별시  서대문구       경찰청어린이집            직장                 90         23.0
# 3    서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 4    서울특별시  서대문구        고은어린이집           국공립                 93         20.0
# 5    서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
# ..     ...   ...           ...           ...                ...          ...
# 96   서울특별시  서대문구        우정어린이집           국공립                 89         17.0
# 97   서울특별시  서대문구        은가어린이집           국공립                 52         11.0
# 98   서울특별시  서대문구        은담어린이집            민간                 39         10.0
# 99   서울특별시  서대문구        은빛어린이집           국공립                 45         10.0
# 100  서울특별시  서대문구        은파어린이집           국공립                 32         10.0
#
# ...

# %%
# index로 추출
# 열 0,3,5를 추출
col1 = [0,3,5]
day_care.iloc[col1]
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 0  서울특별시  서대문구        가람어린이집           국공립                 70         11.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 5  서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 0               5.0             1.0       7.0                    N
# 3               3.0             0.0       4.0                    N
# 5               3.0             0.0       4.0                    N
#
#   reference_date
# 0     2018-07-31
# 3     2018-07-31
# 5     2018-07-31

# %%
# 행 1,3,5를 추출
day_care.iloc[[1,3,5]]
# Out:
#     city    gu day_care_name day_care_type  day_care_baby_num  teacher_num  \
# 1  서울특별시  서대문구      가좌제일어린이집           국공립                 88         22.0
# 3  서울특별시  서대문구      고운햇살어린이집            가정                 18          5.0
# 5  서울특별시  서대문구      그루터기어린이집            가정                 19          3.0
#
#    nursing_room_num  playground_num  CCTV_num is_commuting_vehicle  \
# 1               5.0             2.0      10.0                    N
# 3               3.0             0.0       4.0                    N
# 5               3.0             0.0       4.0                    N
#
#   reference_date
# 1     2018-07-31
# 3     2018-07-31
# 5     2018-07-31

# %%
# 행은 1~10 / 열은 1~3
day_care.iloc[1:11,0:3]
# Out:
#      city    gu day_care_name
# 1   서울특별시  서대문구      가좌제일어린이집
# 2   서울특별시  서대문구       경찰청어린이집
# 3   서울특별시  서대문구      고운햇살어린이집
# 4   서울특별시  서대문구        고은어린이집
# 5   서울특별시  서대문구      그루터기어린이집
# 6   서울특별시  서대문구        금화어린이집
# 7   서울특별시  서대문구       꼬꼬마어린이집
# 8   서울특별시  서대문구      꼬마박사어린이집
# 9   서울특별시  서대문구       꼬마숲어린이집
# 10  서울특별시  서대문구       꾸러기어린이집

# %%
# 행은 2,4,6,8 / 열은 2,4
row2 = [2,4,6,8]
col2 = [2,4]
day_care.iloc[row2,col2]
# Out:
#   day_care_name  day_care_baby_num
# 2       경찰청어린이집                 90
# 4        고은어린이집                 93
# 6        금화어린이집                 86
# 8      꼬마박사어린이집                 19

# %%
# 컬럼명으로 추출해보기

day_care.loc[[2,4,6,8],['day_care_name','day_care_baby_num']]
# Out:
#   day_care_name  day_care_baby_num
# 2       경찰청어린이집                 90
# 4        고은어린이집                 93
# 6        금화어린이집                 86
# 8      꼬마박사어린이집                 19

# %%
tab.iloc[:,-1]
# Out:
# 0       779.445314
# 1       820.853030
# 2       853.100710
# 3       836.197138
# 4       739.981106
#            ...
# 1699    706.157306
# 1700    693.420786
# 1701    792.449960
# 1702    672.038623
# 1703    469.709298
# Name: gdpPercap, Length: 1704, dtype: float64

# %%
small_range = list(range(3,6)) # 3~5
small_range
# Out:
# [3, 4, 5]

# %%
group_year = tab.groupby('year')
group_year

# %%
tab.groupby('year')['pop'].mean()
# Out:
# year
# 1952    1.695040e+07
# 1957    1.876341e+07
# 1962    2.042101e+07
# 1967    2.265830e+07
# 1972    2.518998e+07
# 1977    2.767638e+07
# 1982    3.020730e+07
# 1987    3.303857e+07
# 1992    3.599092e+07
# 1997    3.883947e+07
# 2002    4.145759e+07
# 2007    4.402122e+07
# Name: pop, dtype: float64

# %%
tab.groupby('continent')['pop'].sum()
# Out:
# continent
# Africa       6187585961
# Americas     7351438499
# Asia        30507333901
# Europe       6181115304
# Oceania       212992136
# Name: pop, dtype: int64

# %%
tab.groupby('continent')['pop'].mean()
# Out:
# continent
# Africa      9.916003e+06
# Americas    2.450479e+07
# Asia        7.703872e+07
# Europe      1.716976e+07
# Oceania     8.874672e+06
# Name: pop, dtype: float64

# %%
tab.groupby('continent')['lifeExp'].mean()
# Out:
# continent
# Africa      48.865330
# Americas    64.658737
# Asia        60.064903
# Europe      71.903686
# Oceania     74.326208
# Name: lifeExp, dtype: float64

# %%
tab.groupby('country')['lifeExp'].max()
# Out:
# country
# Afghanistan           43.828
# Albania               76.423
# Algeria               72.301
# Angola                42.731
# Argentina             75.320
#                        ...
# Vietnam               74.249
# West Bank and Gaza    73.422
# Yemen, Rep.           62.698
# Zambia                51.821
# Zimbabwe              62.351
# Name: lifeExp, Length: 142, dtype: float64

# %%
tab.groupby('country')['lifeExp'].min()
# Out:
# country
# Afghanistan           28.801
# Albania               55.230
# Algeria               43.077
# Angola                30.015
# Argentina             62.485
#                        ...
# Vietnam               40.412
# West Bank and Gaza    43.160
# Yemen, Rep.           32.548
# Zambia                39.193
# Zimbabwe              39.989
# Name: lifeExp, Length: 142, dtype: float64

# %%
tab.groupby(['year','continent'])['lifeExp'].mean()
# Out:
# year  continent
# 1952  Africa       39.135500
#       Americas     53.279840
#       Asia         46.314394
#       Europe       64.408500
#       Oceania      69.255000
# 1957  Africa       41.266346
#       Americas     55.960280
#       Asia         49.318544
#       Europe       66.703067
#       Oceania      70.295000
# 1962  Africa       43.319442
#       Americas     58.398760
#       Asia         51.563223
#       Europe       68.539233
#       Oceania      71.085000
# 1967  Africa       45.334538
#       Americas     60.410920
#       Asia         54.663640
#       Europe       69.737600
#       Oceania      71.310000
# 1972  Africa       47.450942
#       Americas     62.394920
#       Asia         57.319269
#       Europe       70.775033
#       Oceania      71.910000
# 1977  Africa       49.580423
#       Americas     64.391560
#       Asia         59.610556
#       Europe       71.937767
#       Oceania      72.855000
# 1982  Africa       51.592865
# ...

# %%
tab.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
Ylife_mean = tab.groupby('year')['lifeExp'].mean()

# %%
Ylife_mean
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
Ylife_mean.plot()

# %%
Clife_mean = tab.groupby('year')['pop'].sum()

# %%
Clife_mean
# Out:
# year
# 1952    2406957150
# 1957    2664404580
# 1962    2899782974
# 1967    3217478384
# 1972    3576977158
# 1977    3930045807
# 1982    4289436840
# 1987    4691477418
# 1992    5110710260
# 1997    5515204472
# 2002    5886977579
# 2007    6251013179
# Name: pop, dtype: int64

# %%
Clife_mean.plot()

# %%
kor = tab.loc[840:851]

# %%
kor
# Out:
#          country continent  year  lifeExp       pop     gdpPercap
# 840  Korea, Rep.      Asia  1952   47.453  20947571   1030.592226
# 841  Korea, Rep.      Asia  1957   52.681  22611552   1487.593537
# 842  Korea, Rep.      Asia  1962   55.292  26420307   1536.344387
# 843  Korea, Rep.      Asia  1967   57.716  30131000   2029.228142
# 844  Korea, Rep.      Asia  1972   62.612  33505000   3030.876650
# 845  Korea, Rep.      Asia  1977   64.766  36436000   4657.221020
# 846  Korea, Rep.      Asia  1982   67.123  39326000   5622.942464
# 847  Korea, Rep.      Asia  1987   69.810  41622000   8533.088805
# 848  Korea, Rep.      Asia  1992   72.244  43805450  12104.278720
# 849  Korea, Rep.      Asia  1997   74.647  46173816  15993.527960
# 850  Korea, Rep.      Asia  2002   77.045  47969150  19233.988180
# 851  Korea, Rep.      Asia  2007   78.623  49044790  23348.139730

# %%
korgdp = kor.groupby('year')['gdpPercap']

# %%
kor.plot('year','gdpPercap')
